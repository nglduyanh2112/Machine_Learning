# %%
import numpy as np

def grad(x):
    return x**2 - 1

def cost(x):
    return (1/3)*x**3 - x

def myGD(x0, eta):
    x = [x0]
    for it in range(100):
        x_new = x[-1] - eta*grad(x[-1])
        if abs(grad(x_new)) < 1e-3:  # just a small number
            break
        x.append(x_new)
    return (x, it)

(x1, it1) = myGD(2, .1)
(x2, it2) = myGD(0.5, .1)

print('Solution x1 = %f, cost = %f, after %d iterations'%(x1[-1], cost(x1[-1]), it1))
print('Solution x2 = %f, cost = %f, after %d iterations'%(x2[-1], cost(x2[-1]), it2))
# Out:
# Solution x1 = 1.000595, cost = -0.666666, after 31 iterations
# Solution x2 = 0.999433, cost = -0.666666, after 32 iterations
